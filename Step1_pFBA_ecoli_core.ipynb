# %%
import cobra, os, re
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
#dir_pfba = './output/pfba/'
#if not os.path.exists(dir_pfba):
#    os.makedirs(dir_pfba)
    
biomId = 'BIOMASS_Ecoli_core_w_GAM'

# %%
modelStart = cobra.io.load_json_model('./input/e_coli_core.json')
modelStart.reactions.EX_glc__D_e.lower_bound = -10. # default
modelStart.reactions.EX_o2_e.lower_bound = -1000. # default
pfba_M9 = cobra.flux_analysis.pfba(modelStart)
gMinMedium = pfba_M9.fluxes[biomId]
#pfba_M9.fluxes.to_csv(dir_pfba + 'pfba_WT_M9.csv', sep='\t')

# %%
gMinMedium
# Out:
# 0.8739215069684309

# %% [markdown]
# Essential rxns from essential gene

# %%
df_ess = pd.read_csv('./input/Ecoli_ess_PECData.dat', sep='\t')
df_ess = df_ess[df_ess['Feature Type(1:gene 2:rRNA 3:tRNA 4:ncRNA 7:tmRNA 8:sRNA)'] == 1]
df_ess = df_ess[df_ess['Class(1:essential 2:noessential 3:unknown)'] == 1]

idx = []
for i in df_ess.index:
    names = df_ess['Alternative name'][i]
    idx.append(re.findall('b\d{4}', names)[0])
df_ess.index = idx

# %%
genes_ess = [g.id for g in modelStart.genes if g.id in df_ess.index]
rxns_from_ess_gene = []

model_raw = modelStart.copy()
model = modelStart.copy()

for gid in genes_ess:
    g = model.genes.get_by_id(gid)
    g.knock_out()
    
    for rxn in g.reactions:
        if rxn.bounds != model_raw.reactions.get_by_id(rxn.id).bounds:
            rxns_from_ess_gene.append(rxn.id)
            
    g.functionall = True
    for rxn in g.reactions:
        rxn.bounds = model_raw.reactions.get_by_id(rxn.id).bounds

# %% [markdown]
# Exchange and transport rxns

# %%
exrxns = [rxn.id for rxn in model.reactions if rxn.id[:3] == 'EX_']
# Excluding PEP:phosphotransferase rxns
tprxns = [rxn.id for rxn in model.reactions if ('t' in rxn.id or 'abc' in rxn.id)\
          and rxn.id not in ['EX_etoh_e, FRUpts2', 'GLCpts']]

# %% [markdown]
# Essential rxns in silico

# %%
model_raw = modelStart.copy()
model = modelStart.copy()

rxns_ess = []
for rxn in model.reactions:
    rxn.knock_out()
    fbako = model.optimize()
    if fbako.status in [None, 'infeasible']:
        print rxn.id
    
    if fbako.f < 0.25*gMinMedium:
        rxns_ess.append(rxn.id)
        
    rxn.bounds = model_raw.reactions.get_by_id(rxn.id).bounds
# Out:
# EX_glc__D_e
# GLCpts
# cobra/util/solver.py:408 UserWarning: solver status is 'infeasible'

# %% [markdown]
# No GPR reactions

# %%
rxns_nogpr = [rxn.id for rxn in model.reactions if rxn.gene_reaction_rule in ['', 's0001']]

# %% [markdown]
# Special case: TKT and Biomass reaction

# %%
rxns_spec = [biomId, 'TKT1', 'TKT2']

# %% [markdown]
# Gather all reactions to be excluded from being KO for mutants

# %%
rxns_excl = rxns_from_ess_gene + exrxns + tprxns + rxns_ess + rxns_spec + rxns_nogpr
rxns_check = [rxn.id for rxn in model.reactions if rxn.id not in rxns_excl]

# %% [markdown]
# Run and record flux

# %%
cols = ['WT'] + [i + '_ko' for i in rxns_check]
rxns_all = [rxn.id for rxn in model.reactions]
df_pfba = pd.DataFrame(index=rxns_all, columns=cols)

model_raw = modelStart.copy()
model = modelStart.copy()

df_pfba.loc[rxns_all, 'WT'] = pfba_M9.fluxes[rxns_all]

for rxnid in rxns_check:
    rxn = model.reactions.get_by_id(rxnid)
    rxn.knock_out()
    pfba = cobra.flux_analysis.pfba(model)
    df_pfba.loc[rxns_all, rxnid + '_ko'] = pfba.fluxes[rxns_all]
        
    rxn.bounds = model_raw.reactions.get_by_id(rxn.id).bounds

# %%
df_pfba.to_csv('./output/pfba_ecoli_core.csv', sep='\t')

# %% [markdown]
# Calculate pairwise Eucledian distance (normalized by number of dimensions)

# %%
cols = ['WT'] + [i + '_ko' for i in rxns_check]
df_pair_dist = pd.DataFrame(index=cols, columns=cols)
for i in cols:
    df_pair_dist.loc[i, i] = 0

rxns_all = [rxn.id for rxn in model.reactions]
for i in range(0, len(cols)-1):
    for j in range(1, len(cols)):
        eu_dist = 0
        for rxnid in rxns_all:
            eu_dist += (abs(df_pfba.loc[rxnid, cols[i]]) - abs(df_pfba.loc[rxnid, cols[j]])) ** 2
        eu_dist = (eu_dist ** 0.5) / len(rxns_all)
        
        df_pair_dist.loc[cols[i], cols[j]] = eu_dist
        df_pair_dist.loc[cols[j], cols[i]] = eu_dist

# %%
for i in cols:
    for j in cols:
        if df_pair_dist.loc[i,j] < 1e-6:
            df_pair_dist.loc[i,j] = 0

# %%
mutants = df_pair_dist.columns

muts_none_all = []
for i in range(0, len(mutants)-1):
    mut1 = mutants[i]
    #print mut1 + ':',
    
    muts_none = []
    for j in range(i+1, len(mutants)):
        mut2 = mutants[j]
        val = df_pair_dist.loc[mut1, mut2]
        if val == 0:
            muts_none.append(mut2)
        
    #print ','.join(muts_none)
    muts_none_all += muts_none
    
muts_none_all = set(muts_none_all)

# %%
idx = [mut for mut in df_pair_dist.index if mut not in muts_none_all]
df_pair_dist = df_pair_dist.loc[idx, idx]

# %%
df_pair_dist.to_csv('./output/pfba_pairwise_distance.csv', sep='\t')

# %%
df_pair_dist
# Out:
#                    WT   AKGDH_ko ATPS4r_ko    FBA_ko    FUM_ko G6PDH2r_ko  \
# WT                  0   0.144243   1.01538  0.809949  0.589936   0.165631
# AKGDH_ko     0.144243          0   1.05119  0.791993  0.573338   0.243635
# ATPS4r_ko     1.01538    1.05119         0   1.46415   1.29449    1.00328
# FBA_ko       0.809949   0.791993   1.46415         0   0.26965   0.904152
# FUM_ko       0.589936   0.573338   1.29449   0.26965         0   0.695295
# G6PDH2r_ko   0.165631   0.243635   1.00328  0.904152  0.695295          0
# GLUDy_ko    0.0939073   0.168013   1.05374   0.80916  0.596358   0.181456
# MDH_ko       0.209194   0.276239   1.09594  0.875164  0.676202   0.196331
# PDH_ko       0.306937   0.341794  0.945041  0.656574  0.460425   0.409045
# PGI_ko       0.163794   0.189607   1.06264  0.677601  0.451412   0.302876
# PPC_ko      0.0885523  0.0699987    1.0273  0.788758  0.566693   0.215369
# PYK_ko       0.064035   0.172717   1.02712  0.831493   0.61583   0.145638
# RPE_ko        0.13704    0.22107   1.00344  0.888072  0.677049  0.0314989
# TALA_ko      0.151593   0.232424   1.00323  0.896404  0.686474    0.01583
#
#              GLUDy_ko    MDH_ko    PDH_ko    PGI_ko     PPC_ko    PYK_ko  \
# WT          0.0939073  0.209194  0.306937  0.163794  0.0885523  0.064035
# AKGDH_ko     0.168013  0.276239  0.341794  0.189607  0.0699987  0.172717
# ATPS4r_ko     1.05374   1.09594  0.945041   1.06264     1.0273   1.02712
# FBA_ko        0.80916  0.875164  0.656574  0.677601   0.788758  0.831493
# FUM_ko       0.596358  0.676202  0.460425  0.451412   0.566693   0.61583
# G6PDH2r_ko   0.181456  0.196331  0.409045  0.302876   0.215369  0.145638
# GLUDy_ko            0  0.203422  0.337638  0.192607   0.131129  0.102794
# MDH_ko       0.203422         0  0.441132  0.315217   0.265797  0.152084
# PDH_ko       0.337638  0.441132         0  0.229493   0.307194  0.338492
# PGI_ko       0.192607  0.315217  0.229493         0   0.153482  0.201788
# PPC_ko       0.131129  0.265797  0.307194  0.153482          0  0.137044
# PYK_ko       0.102794  0.152084  0.338492  0.201788   0.137044         0
# RPE_ko       0.157506   0.18801  0.389388   0.27766   0.189616  0.118971
# TALA_ko      0.169498  0.191605  0.399407  0.290545   0.202684  0.132345
#
#                RPE_ko    TALA_ko
# WT            0.13704   0.151593
# AKGDH_ko      0.22107   0.232424
# ATPS4r_ko     1.00344    1.00323
# FBA_ko       0.888072   0.896404
# FUM_ko       0.677049   0.686474
# G6PDH2r_ko  0.0314989    0.01583
# GLUDy_ko     0.157506   0.169498
# MDH_ko        0.18801   0.191605
# PDH_ko       0.389388   0.399407
# PGI_ko        0.27766   0.290545
# PPC_ko       0.189616   0.202684
# PYK_ko       0.118971   0.132345
# RPE_ko              0  0.0160068
# TALA_ko     0.0160068          0

# %%
df_pfba_filtered = df_pfba.loc[:, idx]

# %%
df_pfba_filtered
# Out:
#                                    WT  AKGDH_ko    ATPS4r_ko    FBA_ko  \
# ACALD                               0         0 -2.81331e-14         0
# ACALDt                              0         0            0         0
# ACKr                      1.93788e-14         0     -14.3123         0
# ACONTa                        6.00725   5.83681     0.403757  0.759585
# ACONTb                        6.00725   5.83681     0.403757  0.759585
# ACt2r                     1.93788e-14         0     -14.3123         0
# ADK1                                0         0            0   4.60743
# AKGDH                         5.06438         0            0         0
# AKGt2r                              0         0            0         0
# ALCD2x                              0         0 -2.81331e-14         0
# ATPM                             8.39      8.39         8.39   21.1135
# ATPS4r                         45.514   47.4282            0   63.7881
# BIOMASS_Ecoli_core_w_GAM     0.873922  0.858307      0.37423  0.704037
# CO2t                         -22.8098  -23.4743     0.668637  -26.6412
# CS                            6.00725   5.83681     0.403757  0.759585
# CYTBD                          43.599    44.964       13.916   55.0527
# D_LACt2                             0         0            0         0
# ENO                           14.7161   14.3901      18.4453   7.77552
# ETOHt2r                             0         0 -2.81331e-14         0
# EX_ac_e                  -1.93788e-14         0      14.3123         0
# EX_acald_e                          0         0            0         0
# EX_akg_e                            0         0            0         0
# EX_co2_e                      22.8098   23.4743    -0.668637   26.6412
# EX_etoh_e                           0         0  2.81331e-14         0
# EX_for_e                            0         0      16.1186   3.39818
# EX_fru_e                            0         0            0         0
# EX_fum_e                            0         0            0         0
# EX_glc__D_e                       -10       -10          -10       -10
# EX_gln__L_e                         0         0            0         0
# EX_glu__L_e                         0         0            0         0
# ...                               ...       ...          ...       ...
# ME2                                 0   2.45121            0         0
# NADH16                        38.5346   40.0532       13.916   55.0527
# NADTRHD                             0         0            0   43.7267
# NH4t                          4.76532   4.68018       2.0406   3.83897
# O2t                           21.7995    22.482        6.958   27.5263
# PDH                           9.28253   13.9644            0         0
# PFK                           7.47738   7.10201      9.62775         0
# PFL                                 0         0      16.1186   3.39818
# PGI                           4.86086   3.69134      9.92328  -18.0434
# PGK                          -16.0235  -15.6741     -19.0052  -8.82876
# PGL                           4.95998   6.13271            0   27.8991
# PGM                          -14.7161  -14.3901     -18.4453  -7.77552
# PIt2r                          3.2149   3.15746      1.37668   2.58994
# PPC                           2.50431         0      1.07239   2.01749
# PPCK                                0         0            0         0
# PPS                                 0         0            0   4.60743
# PTAr                     -1.93788e-14         0      14.3123         0
# PYK                           1.75818   3.94455      7.17868         0
# PYRt2                               0         0            0         0
# RPE                           2.67848   3.47152    -0.268996   18.0933
# RPI                           -2.2815  -2.66119    -0.268996  -9.80576
# SUCCt2_2                            0         0      10.5815         0
# SUCCt3                              0         0      10.5815         0
# SUCDi                         5.06438   4.91078            0         0
# SUCOAS                       -5.06438         0            0         0
# TALA                          1.49698   1.89068   -0.0669497   9.17374
# THD2                                0         0      6.41658         0
# TKT1                          1.49698   1.89068   -0.0669497   9.17374
# TKT2                           1.1815   1.58083    -0.202047   8.91958
# TPI                           7.47738   7.10201      9.62775         0
#
#                                FUM_ko G6PDH2r_ko     GLUDy_ko       MDH_ko  \
# ACALD                               0          0            0            0
# ACALDt                              0          0            0            0
# ACKr                      7.68923e-14          0  1.46274e-14            0
# ACONTa                       0.878546     7.8033      6.47117      8.33976
# ACONTb                       0.878546     7.8033      6.47117      8.33976
# ACt2r                     7.68923e-14          0  1.46274e-14            0
# ADK1                          3.76289          0            0      3.67464
# AKGDH                               0    6.87133      5.55261      7.44879
# AKGt2r                              0          0            0            0
# ALCD2x                              0          0            0            0
# ATPM                             8.39       8.39         8.39         8.39
# ATPS4r                        56.1818    41.3535      47.7439      49.2677
# BIOMASS_Ecoli_core_w_GAM     0.814298   0.863813     0.851389     0.825819
# CO2t                         -25.3472     -23.24     -23.7687     -24.8568
# CS                           0.878546     7.8033      6.47117      8.33976
# CYTBD                         48.8115    44.4827      45.5689      47.8042
# D_LACt2                             0          0            0            0
# ENO                           8.99326    16.4115      14.9555      16.5693
# ETOHt2r                             0          0            0            0
# EX_ac_e                  -7.68923e-14          0 -1.46274e-14            0
# EX_acald_e                          0          0            0            0
# EX_akg_e                            0          0            0            0
# EX_co2_e                      25.3472      23.24      23.7687      24.8568
# EX_etoh_e                           0          0            0            0
# EX_for_e                            0          0            0            0
# EX_fru_e                            0          0            0            0
# EX_fum_e                            0          0            0            0
# EX_glc__D_e                       -10        -10          -10          -10
# EX_gln__L_e                         0          0            0            0
# EX_glu__L_e                         0          0            0            0
# ...                               ...        ...          ...          ...
# ME2                                 0          0            0      6.71079
# NADH16                        48.8115    37.6113      40.0163      40.3554
# NADTRHD                       31.7814          0            0            0
# NH4t                           4.4402     4.7102      4.64245      4.50303
# O2t                           24.4058    22.2413      22.7844      23.9021
# PDH                           3.93037    11.0407        9.662      11.4348
# PFK                           1.56612    9.14076      7.64556      9.17856
# PFL                                 0          0            0            0
# PGI                          -13.0386    9.82292      5.30277      9.83071
# PGK                          -10.2115   -17.7037     -16.2292     -17.8047
# PGL                           22.8717          0      4.52269  3.27828e-12
# PGM                          -8.99326   -16.4115     -14.9555     -16.5693
# PIt2r                         2.99556    3.17771        3.132      3.03794
# PPC                           2.33345    2.47534      2.43974      9.81525
# PPCK                                0          0            0            0
# PPS                           3.76289          0            0      3.67464
# PTAr                     -7.68923e-14          0 -1.46274e-14            0
# PYK                                 0    3.48771      2.07382            0
# PYRt2                               0          0            0            0
# RPE                           14.6625  -0.620909      2.40315    -0.593599
# RPI                          -8.20922  -0.620909     -2.11954    -0.593599
# SUCCt2_2                            0          0            0            0
# SUCCt3                              0          0            0            0
# SUCDi                               0    6.87133      5.55261      7.44879
# SUCOAS                              0   -6.87133     -5.55261     -7.44879
# TALA                          7.47822  -0.154536      1.35525    -0.147739
# THD2                                0     7.9397            0            0
# TKT1                          7.47822  -0.154536      1.35525    -0.147739
# TKT2                          7.18426  -0.466373       1.0479     -0.44586
# TPI                           1.56612    9.14076      7.64556      9.17856
#
#                                PDH_ko       PGI_ko       PPC_ko    PYK_ko  \
# ACALD                               0            0            0         0
# ACALDt                              0            0            0         0
# ACKr                                0 -2.22767e-14 -1.24219e-14         0
# ACONTa                        4.75726      4.53818      5.57361    6.6635
# ACONTb                        4.75726      4.53818      5.57361    6.6635
# ACt2r                               0 -2.22767e-14 -1.24219e-14         0
# ADK1                                0            0            0         0
# AKGDH                         3.89771      3.60692      2.13896   5.73033
# AKGt2r                              0            0            0         0
# ALCD2x                              0            0            0         0
# ATPM                             8.39         8.39         8.39      8.39
# ATPS4r                        43.6718       47.847      46.2027   46.0509
# BIOMASS_Ecoli_core_w_GAM     0.796696      0.86316     0.870745  0.864926
# CO2t                         -18.3531     -23.2678      -22.945  -23.1926
# CS                            4.75726      4.53818      5.57361    6.6635
# CYTBD                         42.6072      44.5398      43.8767   44.3854
# D_LACt2                             0            0            0         0
# ENO                           12.6966      13.1398      14.2508   15.2827
# ETOHt2r                             0            0            0         0
# EX_ac_e                             0  2.22767e-14  1.24219e-14         0
# EX_acald_e                          0            0            0         0
# EX_akg_e                            0            0            0         0
# EX_co2_e                      18.3531      23.2678       22.945   23.1926
# EX_etoh_e                           0            0            0         0
# EX_for_e                      7.74312            0            0         0
# EX_fru_e                            0            0            0         0
# EX_fum_e                            0            0            0         0
# EX_glc__D_e                       -10          -10          -10       -10
# EX_gln__L_e                         0            0            0         0
# EX_glu__L_e                         0            0            0         0
# ...                               ...          ...          ...       ...
# ME2                                 0            0            0   2.35523
# NADH16                        38.7095      40.9329      39.2425   38.6551
# NADTRHD                       14.1997       8.4532            0         0
# NH4t                          4.34422      4.70664        4.748   4.71627
# O2t                           21.3036      22.2699      21.9384   22.1927
# PDH                                 0      7.77313      11.3322   9.90507
# PFK                           5.21382      5.86706      7.00205   8.01557
# PFL                           7.74312            0            0         0
# PGI                          -2.14445            0      3.42604   6.45042
# PGK                          -13.8884     -14.4311     -15.5535  -16.5767
# PGL                           11.9811      9.82305      6.39546   3.37227
# PGM                          -12.6966     -13.1398     -14.2508  -15.2827
# PIt2r                         2.93081      3.17531      3.20321    3.1818
# PPC                           2.28301      2.47347            0   4.83376
# PPCK                                0            0            0         0
# PPS                                 0            0            0         0
# PTAr                                0  2.22767e-14  1.24219e-14         0
# PYK                      -9.85023e-13     0.218289      3.79884         0
# PYRt2                               0            0            0         0
# RPE                           7.41475      5.92826      3.63775   1.62647
# RPI                          -4.56637     -3.89479     -2.75771   -1.7458
# SUCCt2_2                            0            0            0         0
# SUCCt3                              0            0            0         0
# SUCDi                         3.89771      3.60692      4.63417   5.73033
# SUCOAS                       -3.89771     -3.60692     -2.13896  -5.73033
# TALA                          3.85118      3.11993      1.97604  0.969356
# THD2                                0            0            0         0
# TKT1                          3.85118      3.11993      1.97604  0.969356
# TKT2                          3.56357      2.80833       1.6617  0.657117
# TPI                           5.21382      5.86706      7.00205   8.01557
#
#                             RPE_ko   TALA_ko
# ACALD                            0         0
# ACALDt                           0         0
# ACKr                             0         0
# ACONTa                      7.4653   7.63524
# ACONTb                      7.4653   7.63524
# ACt2r                            0         0
# ADK1                             0         0
# AKGDH                      6.53128   6.70225
# AKGt2r                           0         0
# ALCD2x                           0         0
# ATPM                          8.39      8.39
# ATPS4r                     42.1365   41.7428
# BIOMASS_Ecoli_core_w_GAM  0.865716  0.864759
# CO2t                       -23.159  -23.1997
# CS                          7.4653   7.63524
# CYTBD                      44.3164      44.4
# D_LACt2                          0         0
# ENO                        16.0924   16.2528
# ETOHt2r                          0         0
# EX_ac_e                          0         0
# EX_acald_e                       0         0
# EX_akg_e                         0         0
# EX_co2_e                    23.159   23.1997
# EX_etoh_e                        0         0
# EX_for_e                         0         0
# EX_fru_e                         0         0
# EX_fum_e                         0         0
# EX_glc__D_e                    -10       -10
# EX_gln__L_e                      0         0
# EX_glu__L_e                      0         0
# ...                            ...       ...
# ME2                              0         0
# NADH16                     37.7851   37.6977
# NADTRHD                          0         0
# NH4t                       4.72057   4.71536
# O2t                        22.1582      22.2
# PDH                        10.7098   10.8762
# PFK                        8.82773   8.98512
# PFL                              0         0
# PGI                        8.88911   9.35861
# PGK                       -17.3875  -17.5465
# PGL                       0.933415  0.464116
# PGM                       -16.0924  -16.2528
# PIt2r                      3.18471   3.18119
# PPC                        2.48079   2.47805
# PPCK                             0         0
# PPS                              0         0
# PTAr                             0         0
# PYK                        3.16223   3.32588
# PYRt2                            0         0
# RPE                              0 -0.312178
# RPI                      -0.933415 -0.776294
# SUCCt2_2                         0         0
# SUCCt3                           0         0
# SUCDi                      6.53128   6.70225
# SUCOAS                    -6.53128  -6.70225
# TALA                      0.156262         0
# THD2                       6.44553   7.19676
# TKT1                      0.156262         0
# TKT2                     -0.156262 -0.312178
# TPI                        8.82773   8.98512
#
# [95 rows x 14 columns]

# %%
df_pfba_filtered.to_csv('./output/pfba_ecoli_core_filtered.csv', sep='\t')
