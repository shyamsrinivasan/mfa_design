# %%
from optlang import Model, Variable, Constraint, Objective
import pandas as pd
from copy import deepcopy

# %% [markdown]
# Design parameters

# %%
# Load pairwise distance
df_pairdist = pd.read_csv('./output/pfba_pairwise_distance.csv', sep='\t', index_col=0)

# MILP parameters
num_solns = 3 # Number of solutions
num_muts = 3 # Number of mutants

# %% [markdown]
# #### Define model

# %%
model = Model(name='mfa_design')

# %% [markdown]
# #### Define variables

# %%
cols = df_pairdist.columns.tolist()
colpairs = []
for i in range(0, len(cols)-1):
    for j in range(i+1, len(cols)):
        colpairs.append([cols[i], cols[j]])

y_list = [Variable('y__' + i, type='binary', lb=0, ub=1) for i in cols]
r_list = [Variable('__'.join(['r'] + i), type='continuous', lb=0, ub=1) for i in colpairs]

# %%
vars_model = model.variables.keys()
for var in y_list + r_list:
    if var.name not in vars_model:
        model.add(var)
        
y_list = [i.name for i in model.variables if i.name[:3] == 'y__']
r_list = [i.name for i in model.variables if i.name[:3] == 'r__']

# %% [markdown]
# #### Define objective

# %%
c_vector = []
for r_var in r_list:
    i,j = r_var.split('__')[1:]
    c_vector.append(df_pairdist.loc[i,j])
    
obj = Objective(sum(c_vector[i] * model.variables[r_list[i]] for i in range(0, len(r_list))))

# %%
model.objective = obj

# %% [markdown]
# #### Define constraints

# %%
# List 1: r_ij <= y_i
cons_list1 = []
for r_var in r_list:
    r_ij = model.variables[r_var]
    y_i = model.variables['y__' + r_var.split('__')[1]]
    cons_list1.append(Constraint(r_ij - y_i, ub=0))
    
# List 2: r_ij <= y_j
cons_list2 = []
for r_var in r_list:
    r_ij = model.variables[r_var]
    y_j = model.variables['y__' + r_var.split('__')[2]]
    cons_list2.append(Constraint(r_ij - y_j, ub=0))
    
# List 3: r_ij >= y_i + y_j - 1
cons_list3 = []
for r_var in r_list:
    r_ij = model.variables[r_var]
    y_i = model.variables['y__' + r_var.split('__')[1]]
    y_j = model.variables['y__' + r_var.split('__')[2]]
    cons_list3.append(Constraint(r_ij - y_i - y_j, lb=-1))
    
# Constraint 4: sum(y) = L
cons_4 = [Constraint(sum([model.variables[i] for i in y_list]), lb=num_muts, ub=num_muts)]

# Constraint 5: y__WT = 1
cons_5 = [Constraint(model.variables['y__WT'], lb=1, ub=1)]

# %%
model.add(cons_list1 + cons_list2 + cons_list3 + cons_4 + cons_5)

# %% [markdown]
# ### Example 1: Solve

# %%
cols = ['mutants_set', 'sum_pairwise_dist']
df_solns = pd.DataFrame(columns=cols)

for i in range(0, num_solns):
    
    for soln_iter in range(0, i):
        prev_soln = df_solns.mutants_set[soln_iter].split(',')
        cons = Constraint(sum([model.variables['y__' + val] for val in prev_soln]),
                          lb=0, ub=num_muts-1)
        model.add(cons)
        
    model.optimize()
    
    muts = []
    for var in model.variables.values():
        if var.name[:3] == 'y__' and var.primal == 1:
            muts.append(var.name.split('__')[1])
    df_solns.loc[i, 'mutants_set'] = ','.join(muts)
    df_solns.loc[i, 'sum_pairwise_dist'] = model.objective.value

# %%
df_solns
# Out:
#            mutants_set sum_pairwise_dist
# 0  WT,ATPS4r_ko,FBA_ko           3.28948
# 1  WT,ATPS4r_ko,FUM_ko           2.89981
# 2  WT,ATPS4r_ko,MDH_ko           2.32051

# %% [markdown]
# #### Check solutions and debug
# Reason for selection of mutant:<br>
# ATPS4r: Switch to acetate and formate fermentation<br>
# FBA: Switch to PPP (thus higher PPP flux) and ferment formate<br>
# FUM: Switch to PPP<br>
# MDH: Higher TCA flux, activation of malic enzyme<br>

# %%
df_pfba = pd.read_csv('./output/pfba_ecoli_core_filtered2.csv', sep='\t', index_col=0)
df_pfba.loc[:, ['WT', 'ATPS4r_ko', 'FBA_ko', 'FUM_ko', 'MDH_ko']]

# %% [markdown]
# ### Example 2: Solve with ATP synthase KO exclusion

# %%
model_noATPS = deepcopy(model)
model_noATPS.add(Constraint(model_noATPS.variables['y__ATPS4r_ko'], lb=0, ub=0))

# %%
cols = ['mutants_set', 'sum_pairwise_dist']
df_solns2 = pd.DataFrame(columns=cols)

for i in range(0, num_solns):
    
    for soln_iter in range(0, i):
        prev_soln = df_solns2.mutants_set[soln_iter].split(',')
        cons = Constraint(sum([model_noATPS.variables['y__' + val] for val in prev_soln]),
                          lb=0, ub=num_muts-1)
        model_noATPS.add(cons)
        
    model_noATPS.optimize()
    
    muts = []
    for var in model_noATPS.variables.values():
        if var.name[:3] == 'y__' and var.primal == 1:
            muts.append(var.name.split('__')[1])
    df_solns2.loc[i, 'mutants_set'] = ','.join(muts)
    df_solns2.loc[i, 'sum_pairwise_dist'] = model_noATPS.objective.value

# %%
df_solns2
# Out:
#             mutants_set sum_pairwise_dist
# 0      WT,FBA_ko,MDH_ko           1.89431
# 1  WT,FBA_ko,G6PDH2r_ko           1.87973
# 2     WT,FBA_ko,TALA_ko           1.85795

# %% [markdown]
# #### Check solutions and debug
# Reason for selection of mutant:<br>
# FBA: Switch to PPP (thus higher PPP flux) and ferment formate<br>
# MDH: Higher TCA flux, activation of malic enzyme<br>
# G6PDH2r: Higher (but less than MDH KO) TCA flux, higher EMP flux<br>
# TALA: Higher (but less than MDH KO) TCA flux, higher EMP flux<br>

# %%
df_pfba = pd.read_csv('./output/pfba_ecoli_core_filtered2.csv', sep='\t', index_col=0)
df_pfba.loc[:, ['WT', 'FBA_ko', 'MDH_ko', 'G6PDH2r_ko', 'TALA_ko']]
# Out:
#                                  WT     FBA_ko     MDH_ko  G6PDH2r_ko  \
# ACKr                       0.000000   0.000000   0.000000    0.000000
# ACONTa                     6.007250   0.759585   8.339762    7.803302
# ACONTb                     6.007250   0.759585   8.339762    7.803302
# ACt2r                      0.000000   0.000000   0.000000    0.000000
# ADK1                       0.000000   4.607429   3.674637    0.000000
# AKGDH                      5.064376   0.000000   7.448786    6.871333
# ATPM                       8.390000  21.113487   8.390000    8.390000
# ATPS4r                    45.514010  63.788053  49.267736   41.353546
# BIOMASS_Ecoli_core_w_GAM   0.873922   0.704037   0.825819    0.863813
# CO2t                     -22.809833 -26.641181 -24.856847  -23.239993
# CS                         6.007250   0.759585   8.339762    7.803302
# CYTBD                     43.598985  55.052662  47.804235   44.482676
# ENO                       14.716140   7.775525  16.569299   16.411460
# EX_ac_e                    0.000000   0.000000   0.000000    0.000000
# EX_co2_e                  22.809833  26.641181  24.856847   23.239993
# EX_for_e                   0.000000   3.398175   0.000000    0.000000
# EX_glc__D_e              -10.000000 -10.000000 -10.000000  -10.000000
# EX_h_e                    17.530865  17.521156  16.565935   17.328095
# EX_h2o_e                  29.175827  31.769667  30.872445   29.532354
# EX_nh4_e                  -4.765319  -3.838973  -4.503027   -4.710201
# EX_o2_e                  -21.799493 -27.526331 -23.902117  -22.241338
# EX_pi_e                   -3.214895  -2.589941  -3.037941   -3.177710
# FBA                        7.477382   0.000000   9.178558    9.140765
# FORt                       0.000000  -3.398175   0.000000    0.000000
# FUM                        5.064376   0.000000   7.448786    6.871333
# G6PDH2r                    4.959985  27.899083   0.000000    0.000000
# GAPD                      16.023526   8.828764  17.804725   17.703725
# GLCpts                    10.000000  10.000000  10.000000   10.000000
# GLNS                       0.223462   0.180022   0.211162    0.220877
# GLUDy                     -4.541857  -3.658950  -4.291865   -4.489324
# GLUSy                      0.000000   0.000000   0.000000    0.000000
# GND                        4.959985  27.899083   0.000000    0.000000
# H2Ot                     -29.175827 -31.769667 -30.872445  -29.532354
# ICDHyr                     6.007250   0.759585   8.339762    7.803302
# ICL                        0.000000   0.000000   0.000000    0.000000
# MALS                       0.000000   0.000000   0.000000    0.000000
# MDH                        5.064376   0.000000   0.000000    6.871333
# ME1                        0.000000   0.000000   0.737991    0.000000
# ME2                        0.000000   0.000000   6.710795    0.000000
# NADH16                    38.534610  55.052662  40.355449   37.611343
# NADTRHD                    0.000000  43.726679   0.000000    0.000000
# NH4t                       4.765319   3.838973   4.503027    4.710201
# O2t                       21.799493  27.526331  23.902117   22.241338
# PDH                        9.282533   0.000000  11.434767   11.040701
# PFK                        7.477382   0.000000   9.178558    9.140765
# PFL                        0.000000   3.398175   0.000000    0.000000
# PGI                        4.860861 -18.043411   9.830707    9.822918
# PGK                      -16.023526  -8.828764 -17.804725  -17.703725
# PGL                        4.959985  27.899083   0.000000    0.000000
# PGM                      -14.716140  -7.775525 -16.569299  -16.411460
# PIt2r                      3.214895   2.589941   3.037941    3.177710
# PPC                        2.504309   2.017488   9.815253    2.475343
# PPS                        0.000000   4.607429   3.674637    0.000000
# PTAr                       0.000000   0.000000   0.000000    0.000000
# PYK                        1.758177   0.000000   0.000000    3.487711
# RPE                        2.678482  18.093327  -0.593599   -0.620909
# RPI                       -2.281503  -9.805756  -0.593599   -0.620909
# SUCCt2_2                   0.000000   0.000000   0.000000    0.000000
# SUCCt3                     0.000000   0.000000   0.000000    0.000000
# SUCDi                      5.064376   0.000000   7.448786    6.871333
# SUCOAS                    -5.064376   0.000000  -7.448786   -6.871333
# TALA                       1.496984   9.173742  -0.147739   -0.154536
# THD2                       0.000000   0.000000   0.000000    7.939696
# TKT1                       1.496984   9.173742  -0.147739   -0.154536
# TKT2                       1.181498   8.919585  -0.445860   -0.466373
# TPI                        7.477382   0.000000   9.178558    9.140765
#
#                             TALA_ko
# ACKr                       0.000000
# ACONTa                     7.635241
# ACONTb                     7.635241
# ACt2r                      0.000000
# ADK1                       0.000000
# AKGDH                      6.702253
# ATPM                       8.390000
# ATPS4r                    41.742849
# BIOMASS_Ecoli_core_w_GAM   0.864759
# CO2t                     -23.199742
# CS                         7.635241
# CYTBD                     44.399987
# ENO                       16.252826
# EX_ac_e                    0.000000
# EX_co2_e                  23.199742
# EX_for_e                   0.000000
# EX_glc__D_e              -10.000000
# EX_h_e                    17.347069
# EX_h2o_e                  29.498993
# EX_nh4_e                  -4.715359
# EX_o2_e                  -22.199994
# EX_pi_e                   -3.181190
# FBA                        8.985119
# FORt                       0.000000
# FUM                        6.702253
# G6PDH2r                    0.464116
# GAPD                      17.546505
# GLCpts                    10.000000
# GLNS                       0.221119
# GLUDy                     -4.494240
# GLUSy                      0.000000
# GND                        0.464116
# H2Ot                     -29.498993
# ICDHyr                     7.635241
# ICL                        0.000000
# MALS                       0.000000
# MDH                        6.702253
# ME1                        0.000000
# ME2                        0.000000
# NADH16                    37.697735
# NADTRHD                    0.000000
# NH4t                       4.715359
# O2t                       22.199994
# PDH                       10.876186
# PFK                        8.985119
# PFL                        0.000000
# PGI                        9.358608
# PGK                      -17.546505
# PGL                        0.464116
# PGM                      -16.252826
# PIt2r                      3.181190
# PPC                        2.478054
# PPS                        0.000000
# PTAr                       0.000000
# PYK                        3.325875
# RPE                       -0.312178
# RPI                       -0.776294
# SUCCt2_2                   0.000000
# SUCCt3                     0.000000
# SUCDi                      6.702253
# SUCOAS                    -6.702253
# TALA                       0.000000
# THD2                       7.196762
# TKT1                       0.000000
# TKT2                      -0.312178
# TPI                        8.985119
